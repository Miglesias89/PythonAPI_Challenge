# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

#weather_api_key = "fffb9384b53ddddafa48bf6bfe146a5b"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "https://api.openweathermap.org/data/2.5/weather?q=" 
units = "imperial"

citydata = []

i = 0

for city in cities:
    #print(city)
    i = i + 1
    url = base_url + city + "&appid=" + weather_api_key + "&units=" + units
    try:
        response = requests.get(url).json()
        temperature= response["main"]["temp"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        humidity = response["main"]["humidity"]
        wind_speed = response["wind"]["speed"]
        cloudiness = response["clouds"]["all"]
        country = response["sys"]["country"]
        date = response["dt"]
        citydata.append({"City": city,
                         "Country": country,
                         "Date": date,
                        "Temperature": temperature,
                        "Latitude": latitude,
                        "Longitude": longitude,
                        "Humidity": humidity,
                        "Wind Speed": wind_speed,
                        "Cloudiness": cloudiness,})
        
        print(f'Record no.{i}|{city}')
        
        time.sleep(0.2)
    
    #If no record found then pass to the next city
    except:
        print(f'City not found')
        pass
# Out:
# Record no.1|la ronge
# Record no.2|saint-philippe
# Record no.3|plouzane
# Record no.4|porto santo
# Record no.5|zhigansk
# Record no.6|saint-pierre
# Record no.7|frutal
# Record no.8|huayang
# Record no.9|busselton
# Record no.10|albany
# Record no.11|olafsvik
# Record no.12|jurm
# Record no.13|horta
# Record no.14|punta arenas
# Record no.15|olutanga
# Record no.16|wencheng
# Record no.17|grindavik
# Record no.18|rikitea
# Record no.19|kavaratti
# Record no.20|ryotsu
# Record no.21|luderitz
# Record no.22|ushuaia
# Record no.23|tromso
# Record no.24|tezu
# Record no.25|cidreira
# Record no.26|port alfred
# Record no.27|nanortalik
# Record no.28|kotido
# Record no.29|krasnoselkup
# Record no.30|richards bay
# Record no.31|maromitsa
# Record no.32|mayma
# Record no.33|broome
# Record no.34|mataura
# Record no.35|georgetown
# Record no.36|new norfolk
# Record no.37|asyut
# Record no.38|port blair
# Record no.39|gandorhun
# City not found
# Record no.41|vao
# Record no.42|rocha
# Record no.43|mandalgovi
# Record no.44|touros
# Record no.45|arkhangelsk
# Record no.46|carnarvon
# Record no.47|thompson
# Record no.48|san patricio
# Record no.49|ilhabela
# Record no.50|atar
# Record no.51|leningradskiy
# Record no.52|sabha
# Record no.53|westport
# City not found
# Record no.55|cabo san lucas
# Record no.56|los llanos de aridane
# Record no.57|maraa
# Record no.58|ostrovnoy
# Record no.59|port elizabeth
# Record no.60|canas
# Record no.61|bluff
# Record no.62|dingle
# Record no.63|alberdi
# City not found
# Record no.65|kaitangata
# Record no.66|atuona
# Record no.67|bethel
# Record no.68|platanos
# Record no.69|jamestown
# Record no.70|glinka
# City not found
# Record no.72|butaritari
# Record no.73|mar del plata
# Record no.74|lompoc
# Record no.75|saint-ambroise
# Record no.76|bengkulu
# Record no.77|lerwick
# Record no.78|manica
# Record no.79|tuktoyaktuk
# Record no.80|mbaiki
# Record no.81|vostok
# Record no.82|alberton
# Record no.83|castro
# Record no.84|acapulco
# Record no.85|fond du lac
# Record no.86|kapaa
# Record no.87|bredasdorp
# Record no.88|pitimbu
# Record no.89|requena
# Record no.90|avarua
# Record no.91|vryburg
# Record no.92|zyryanka
# Record no.93|mehar
# Record no.94|huanren
# Record no.95|vaini
# Record no.96|charters towers
# Record no.97|nizhniy kuranakh
# Record no.98|rawson
# City not found
# City not found
# Record no.101|chute-aux-outardes
# Record no.102|east london
# Record no.103|diego de almagro
# Record no.104|cilegon
# Record no.105|malayal
# Record no.106|nikolskoye
# Record no.107|jaru
# Record no.108|hobart
# Record no.109|vardo
# Record no.110|hami
# Record no.111|cherskiy
# Record no.112|coahuayana
# Record no.113|upernavik
# Record no.114|bridgeton
# Record no.115|arraial do cabo
# Record no.116|egvekinot
# City not found
# Record no.118|turochak
# Record no.119|conneaut
# Record no.120|mayo
# Record no.121|kodiak
# Record no.122|san carlos del zulia
# Record no.123|skovorodino
# Record no.124|progreso
# Record no.125|saskylakh
# Record no.126|chara
# Record no.127|cape town
# Record no.128|olinda
# Record no.129|algiers
# Record no.130|shenjiamen
# Record no.131|faanui
# Record no.132|sainte-maxime
# City not found
# Record no.134|hambantota
# Record no.135|chokurdakh
# Record no.136|ancud
# Record no.137|husavik
# Record no.138|hofn
# Record no.139|colac
# Record no.140|pevek
# Record no.141|marolambo
# Record no.142|ambilobe
# Record no.143|borba
# Record no.144|borshchiv
# Record no.145|paamiut
# Record no.146|ribeira grande
# Record no.147|emba
# Record no.148|hilo
# Record no.149|terney
# City not found
# City not found
# Record no.152|tuatapere
# Record no.153|taltal
# Record no.154|mahebourg
# City not found
# Record no.156|barrow
# Record no.157|hithadhoo
# Record no.158|sur
# City not found
# Record no.160|bambous virieux
# Record no.161|clyde river
# Record no.162|puerto ayora
# Record no.163|chuy
# Record no.164|sterling
# Record no.165|victoria
# Record no.166|yellowknife
# Record no.167|nagaoka
# Record no.168|portland
# Record no.169|tasiilaq
# Record no.170|mehran
# Record no.171|sao gabriel da cachoeira
# Record no.172|ust-maya
# Record no.173|mehamn
# Record no.174|cockburn town
# Record no.175|provideniya
# Record no.176|marsabit
# Record no.177|congleton
# Record no.178|airai
# Record no.179|nabire
# Record no.180|souillac
# Record no.181|mount gambier
# Record no.182|puerto colombia
# Record no.183|haapiti
# Record no.184|ferrol
# Record no.185|podor
# Record no.186|sao joao da barra
# Record no.187|avera
# Record no.188|saint-joseph
# Record no.189|gerede
# City not found
# Record no.191|saint george
# Record no.192|timizart
# Record no.193|lagoa
# Record no.194|livingston
# Record no.195|shingu
# Record no.196|noyabrsk
# Record no.197|andenes
# Record no.198|hammerfest
# Record no.199|fairbanks
# Record no.200|port lincoln
# Record no.201|khatanga
# Record no.202|mantes-la-ville
# Record no.203|pangnirtung
# Record no.204|tweed
# Record no.205|pangody
# Record no.206|mwinilunga
# Record no.207|bagar
# Record no.208|amga
# Record no.209|vanimo
# Record no.210|saint-augustin
# Record no.211|kruisfontein
# Record no.212|sharjah
# Record no.213|bani walid
# City not found
# Record no.215|kahului
# Record no.216|hamilton
# Record no.217|brae
# Record no.218|price
# Record no.219|chapada dos guimaraes
# Record no.220|lugoba
# Record no.221|norman wells
# Record no.222|yakeshi
# City not found
# Record no.224|lao cai
# Record no.225|beipiao
# Record no.226|cartagena
# Record no.227|kandalaksha
# Record no.228|ilulissat
# Record no.229|mitu
# Record no.230|danszentmiklos
# Record no.231|bairiki
# Record no.232|worthington
# Record no.233|muromtsevo
# Record no.234|yulara
# Record no.235|el bosque
# Record no.236|hermanus
# Record no.237|santa cruz cabralia
# Record no.238|san quintin
# Record no.239|kaeo
# Record no.240|goias
# Record no.241|palmer
# Record no.242|bam
# Record no.243|ankang
# Record no.244|ahipara
# Record no.245|bejar
# Record no.246|dikson
# Record no.247|kirakira
# Record no.248|saldanha
# Record no.249|umm lajj
# Record no.250|geraldton
# Record no.251|karratha
# Record no.252|thinadhoo
# City not found
# Record no.254|krymsk
# Record no.255|wau
# Record no.256|zhumadian
# Record no.257|nouadhibou
# Record no.258|qaanaaq
# Record no.259|lasa
# Record no.260|codrington
# Record no.261|tignere
# Record no.262|dalbandin
# Record no.263|kostomuksha
# Record no.264|kargasok
# Record no.265|male
# Record no.266|gillette
# Record no.267|te anau
# Record no.268|praia da vitoria
# Record no.269|menongue
# Record no.270|abalak
# Record no.271|ellisras
# Record no.272|antipolo
# Record no.273|kavieng
# Record no.274|luanda
# Record no.275|uusikaupunki
# Record no.276|swidwin
# Record no.277|catabola
# Record no.278|santa maria
# City not found
# Record no.280|christchurch
# Record no.281|talnakh
# Record no.282|along
# Record no.283|lazarev
# Record no.284|nemuro
# Record no.285|trincomalee
# Record no.286|buncrana
# Record no.287|nelson bay
# Record no.288|north bend
# Record no.289|foumban
# Record no.290|fort nelson
# Record no.291|lavrentiya
# Record no.292|ushtobe
# City not found
# Record no.294|pishin
# Record no.295|constitucion
# Record no.296|lazaro cardenas
# Record no.297|bom jesus
# City not found
# Record no.299|del rio
# City not found
# Record no.301|makakilo city
# City not found
# Record no.303|sao filipe
# Record no.304|lukulu
# Record no.305|mount isa
# Record no.306|toyooka
# Record no.307|takoradi
# Record no.308|aseri
# City not found
# Record no.310|abha
# City not found
# Record no.312|san rafael
# Record no.313|aklavik
# Record no.314|mahibadhoo
# Record no.315|byron bay
# Record no.316|praya
# Record no.317|mariana
# Record no.318|dongying
# Record no.319|bonavista
# Record no.320|belmonte
# Record no.321|coquimbo
# Record no.322|sumenep
# Record no.323|bakani
# Record no.324|aguimes
# Record no.325|bandarbeyla
# City not found
# Record no.327|tank
# Record no.328|katherine
# Record no.329|pangani
# Record no.330|katobu
# Record no.331|platteville
# Record no.332|xaxim
# Record no.333|longyearbyen
# Record no.334|tucurui
# Record no.335|vanavara
# Record no.336|isabela
# Record no.337|barentu
# Record no.338|cochabamba
# Record no.339|batagay
# Record no.340|henties bay
# Record no.341|pisco
# Record no.342|barra patuca
# Record no.343|hilton head island
# Record no.344|luis correia
# Record no.345|novyy urengoy
# Record no.346|adolfo lopez mateos
# Record no.347|bayangol
# Record no.348|lexington
# Record no.349|hattiesburg
# Record no.350|wenling
# Record no.351|kieta
# Record no.352|tolaga bay
# Record no.353|japura
# Record no.354|shache
# Record no.355|ponta do sol
# Record no.356|krasnokholm
# Record no.357|mindelo
# Record no.358|kishi
# Record no.359|berlevag
# Record no.360|maniitsoq
# Record no.361|tukrah
# Record no.362|bandar-e lengeh
# Record no.363|san policarpo
# Record no.364|kiama
# Record no.365|atbasar
# Record no.366|fortuna
# City not found
# City not found
# Record no.369|pila
# Record no.370|urcos
# City not found
# Record no.372|dwarka
# City not found
# Record no.374|komsomolskiy
# Record no.375|shubarkuduk
# Record no.376|tura
# Record no.377|quang ngai
# Record no.378|halifax
# Record no.379|adrar
# Record no.380|daru
# Record no.381|hay river
# Record no.382|victor harbor
# Record no.383|klaksvik
# Record no.384|malanje
# City not found
# Record no.386|nuevo progreso
# Record no.387|yumen
# Record no.388|rassvet
# Record no.389|truth or consequences
# Record no.390|nishihara
# Record no.391|erenhot
# Record no.392|eufaula
# Record no.393|gulf gate estates
# City not found
# Record no.395|katsuura
# Record no.396|dongsheng
# Record no.397|oistins
# Record no.398|dzhebariki-khaya
# City not found
# Record no.400|leh
# Record no.401|hansot
# Record no.402|ballina
# City not found
# Record no.404|hofu
# Record no.405|wuda
# Record no.406|bahir dar
# Record no.407|pimenteiras
# Record no.408|rundu
# Record no.409|ust-ilimsk
# Record no.410|hobyo
# Record no.411|laguna
# Record no.412|guerrero negro
# Record no.413|bukene
# Record no.414|evensk
# Record no.415|alofi
# Record no.416|puerto madero
# Record no.417|baykalovo
# Record no.418|mecca
# Record no.419|andreapol
# Record no.420|batemans bay
# Record no.421|torbay
# Record no.422|catalao
# Record no.423|virginia beach
# Record no.424|balkhash
# Record no.425|walvis bay
# Record no.426|iquitos
# Record no.427|manta
# Record no.428|huarmey
# Record no.429|gornopravdinsk
# Record no.430|broken hill
# Record no.431|severnyy
# Record no.432|morondava
# Record no.433|bubaque
# Record no.434|sitka
# Record no.435|tazovskiy
# Record no.436|bathsheba
# Record no.437|ipswich
# Record no.438|kumluca
# Record no.439|tual
# Record no.440|namtsy
# Record no.441|omboue
# City not found
# Record no.443|humaita
# Record no.444|cayenne
# Record no.445|carlentini
# Record no.446|joao pinheiro
# Record no.447|barquisimeto
# Record no.448|severo-kurilsk
# Record no.449|bahia blanca
# Record no.450|chekhov
# Record no.451|huilong
# Record no.452|yantzaza
# Record no.453|sampit
# Record no.454|maarianhamina
# Record no.455|kibala
# Record no.456|kharp
# Record no.457|westlock
# Record no.458|korla
# Record no.459|roma
# Record no.460|sistranda
# Record no.461|tiksi
# Record no.462|lebu
# Record no.463|big rapids
# Record no.464|tourlaville
# Record no.465|sisophon
# Record no.466|santa cruz
# Record no.467|taos
# Record no.468|nizwa
# Record no.469|vung tau
# Record no.470|kushima
# Record no.471|sussex
# Record no.472|pochutla
# Record no.473|petropavlovsk-kamchatskiy
# Record no.474|nador
# Record no.475|ixtapa
# Record no.476|mercedes
# Record no.477|lorengau
# Record no.478|beringovskiy
# Record no.479|baruun-urt
# Record no.480|uray
# Record no.481|narasannapeta
# Record no.482|yenotayevka
# City not found
# Record no.484|bilma
# Record no.485|havre-saint-pierre
# Record no.486|pangai
# Record no.487|okha
# Record no.488|faya
# Record no.489|kaseda
# Record no.490|irituia
# Record no.491|rio grande
# Record no.492|farah
# Record no.493|fort collins
# Record no.494|itarema
# Record no.495|ekhabi
# Record no.496|arvika
# Record no.497|isangel
# Record no.498|milos
# Record no.499|suntar
# City not found
# Record no.501|nantucket
# Record no.502|nome
# Record no.503|gat
# Record no.504|darlawn
# Record no.505|udachnyy
# Record no.506|kidal
# Record no.507|buraydah
# Record no.508|grand-santi
# Record no.509|niihama
# Record no.510|mersing
# Record no.511|taoudenni
# City not found
# Record no.513|punghina
# City not found
# City not found
# Record no.516|malakal
# Record no.517|morehead
# Record no.518|kumher
# Record no.519|ozinki
# Record no.520|calera
# Record no.521|bac lieu
# Record no.522|oxford
# Record no.523|puerto carreno
# City not found
# Record no.525|espanola
# Record no.526|wanning
# Record no.527|champerico
# Record no.528|voronovytsya
# Record no.529|salalah
# Record no.530|beryslav
# Record no.531|angoche
# Record no.532|srandakan
# Record no.533|lata
# Record no.534|belyy yar
# Record no.535|mana
# City not found
# Record no.537|alice springs
# City not found
# Record no.539|oxapampa
# City not found
# Record no.541|agadez
# Record no.542|perth
# Record no.543|corinto
# Record no.544|kloulklubed
# City not found
# Record no.546|hasaki
# Record no.547|amarkantak
# Record no.548|inhambane
# Record no.549|bowen
# Record no.550|burlington
# Record no.551|tabas
# City not found
# Record no.553|varhaug
# Record no.554|duvan
# Record no.555|flin flon
# Record no.556|senekal
# Record no.557|revuca
# Record no.558|muroto
# Record no.559|kaduna
# City not found
# Record no.561|waingapu
# Record no.562|saint-francois
# Record no.563|hervey bay
# Record no.564|bagdarin
# City not found
# Record no.566|libourne
# Record no.567|half moon bay
# Record no.568|oktyabrskiy
# Record no.569|the valley
# Record no.570|namibe
# Record no.571|kyren
# Record no.572|mwense
# Record no.573|nsanje
# Record no.574|eucaliptus
# Record no.575|anahuac
# Record no.576|kabo
# Record no.577|college
# Record no.578|ormara
# Record no.579|nyurba
# Record no.580|nouakchott
# Record no.581|naze
# Record no.582|saint pete beach
# Record no.583|nyimba
# Record no.584|tazmalt
# Record no.585|abu kamal
# Record no.586|kikwit
# Record no.587|tonantins
# Record no.588|gualaquiza
# Record no.589|kankon
# Record no.590|severnyy-kospashskiy
# Record no.591|hirara
# Record no.592|shamary
# Record no.593|ulladulla
# Record no.594|unai
# Record no.595|talcahuano
# Record no.596|maba
# Record no.597|sao joao do piaui
# Record no.598|santa cruz das palmeiras
# Record no.599|carutapera
# Record no.600|barcelos
# Record no.601|coachella
# Record no.602|qaqortoq
# Record no.603|marrakesh
# Record no.604|chumikan
# Record no.605|ugoofaaru
# Record no.606|bambanglipuro
# Record no.607|seoul
# Record no.608|vila velha
# Record no.609|alenquer
# Record no.610|mamallapuram
# Record no.611|havoysund
# Record no.612|celestun
# Record no.613|yevlax
# Record no.614|havelock
# Record no.615|banjar
# Record no.616|port hardy
# Record no.617|lavumisa
# Record no.618|visby
# Record no.619|sosnogorsk
# Record no.620|okhotsk
# Record no.621|katangli
# Record no.622|esperance
# Record no.623|ariquemes
# City not found
# Record no.625|walla walla
# Record no.626|margate
# Record no.627|beihai
# Record no.628|cortez
# Record no.629|tungor

# %%
print(citydata)
# Out:
# [{'City': 'la ronge', 'Country': 'CA', 'Date': 1586552041, 'Temperature': 28.4, 'Latitude': 55.1, 'Longitude': -105.28, 'Humidity': 63, 'Wind Speed': 17.22, 'Cloudiness': 90}, {'City': 'saint-philippe', 'Country': 'RE', 'Date': 1586551639, 'Temperature': 69.85, 'Latitude': -21.36, 'Longitude': 55.77, 'Humidity': 78, 'Wind Speed': 10.29, 'Cloudiness': 20}, {'City': 'plouzane', 'Country': 'FR', 'Date': 1586552042, 'Temperature': 59.05, 'Latitude': 48.38, 'Longitude': -4.62, 'Humidity': 67, 'Wind Speed': 3.36, 'Cloudiness': 0}, {'City': 'porto santo', 'Country': 'PT', 'Date': 1586551770, 'Temperature': 64.92, 'Latitude': 33.07, 'Longitude': -16.34, 'Humidity': 77, 'Wind Speed': 9.17, 'Cloudiness': 20}, {'City': 'zhigansk', 'Country': 'RU', 'Date': 1586552043, 'Temperature': 19.54, 'Latitude': 66.77, 'Longitude': 123.37, 'Humidity': 94, 'Wind Speed': 11.48, 'Cloudiness': 0}, {'City': 'saint-pierre', 'Country': 'RE', 'Date': 1586551658, 'Temperature': 70.66, 'Latitude': -21.34, 'Longitude': 55.48, 'Humidity': 78, 'Wind Speed': 10.29, 'Cloudiness': 20}, {'City': 'frutal', 'Country': 'BR', 'Date': 1586552044, 'Temperature': 70.09, 'Latitude': -20.02, 'Longitude': -48.94, 'Humidity': 61, 'Wind Speed': 2.3, 'Cloudiness': 0}, {'City': 'huayang', 'Country': 'CN', 'Date': 1586552044, 'Temperature': 31.91, 'Latitude': 34.42, 'Longitude': 109.99, 'Humidity': 68, 'Wind Speed': 3.27, 'Cloudiness': 71}, {'City': 'busselton', 'Country': 'AU', 'Date': 1586551793, 'Temperature': 65.46, 'Latitude': -33.65, 'Longitude': 115.33, 'Humidity': 52, 'Wind Speed': 12.15, 'Cloudiness': 56}, {'City': 'albany', 'Country': 'US', 'Date': 1586551639, 'Temperature': 42.12, 'Latitude': 42.6, 'Longitude': -73.97, 'Humidity': 61, 'Wind Speed': 19.46, 'Cloudiness': 90}, {'City': 'olafsvik', 'Country': 'IS', 'Date': 1586551660, 'Temperature': 36.3, 'Latitude': 64.89, 'Longitude': -23.71, 'Humidity': 79, 'Wind Speed': 14.23, 'Cloudiness': 25}, {'City': 'jurm', 'Country': 'AF', 'Date': 1586552046, 'Temperature': 51.8, 'Latitude': 36.86, 'Longitude': 70.83, 'Humidity': 23, 'Wind Speed': 7.99, 'Cloudiness': 100}, {'City': 'horta', 'Country': 'PT', 'Date': 1586551852, 'Temperature': 64.4, 'Latitude': 38.53, 'Longitude': -28.63, 'Humidity': 77, 'Wind Speed': 3.36, 'Cloudiness': 40}, {'City': 'punta arenas', 'Country': 'CL', 'Date': 1586551448, 'Temperature': 46.2, 'Latitude': -53.15, 'Longitude': -70.92, 'Humidity': 70, 'Wind Speed': 11.41, 'Cloudiness': 75}, {'City': 'olutanga', 'Country': 'PH', 'Date': 1586552048, 'Temperature': 80.37, 'Latitude': 7.31, 'Longitude': 122.85, 'Humidity': 75, 'Wind Speed': 2.86, 'Cloudiness': 14}, {'City': 'wencheng', 'Country': 'CN', 'Date': 1586552048, 'Temperature': 42.21, 'Latitude': 33.06, 'Longitude': 113.8, 'Humidity': 89, 'Wind Speed': 11.56, 'Cloudiness': 100}, {'City': 'grindavik', 'Country': 'IS', 'Date': 1586551859, 'Temperature': 40.05, 'Latitude': 63.84, 'Longitude': -22.43, 'Humidity': 86, 'Wind Speed': 14.99, 'Cloudiness': 90}, {'City': 'rikitea', 'Country': 'PF', 'Date': 1586551654, 'Temperature': 77, 'Latitude': -23.12, 'Longitude': -134.97, 'Humidity': 74, 'Wind Speed': 5.95, 'Cloudiness': 77}, {'City': 'kavaratti', 'Country': 'IN', 'Date': 1586551990, 'Temperature': 83.95, 'Latitude': 10.57, 'Longitude': 72.64, 'Humidity': 70, 'Wind Speed': 6.78, 'Cloudiness': 0}, {'City': 'ryotsu', 'Country': 'JP', 'Date': 1586552050, 'Temperature': 37.4, 'Latitude': 38.08, 'Longitude': 138.43, 'Humidity': 86, 'Wind Speed': 3.36, 'Cloudiness': 0}, {'City': 'luderitz', 'Country': 'NA', 'Date': 1586551664, 'Temperature': 59, 'Latitude': -26.65, 'Longitude': 15.16, 'Humidity': 82, 'Wind Speed': 3.36, 'Cloudiness': 0}, {'City': 'ushuaia', 'Country': 'AR', 'Date': 1586551656, 'Temperature': 48.2, 'Latitude': -54.8, 'Longitude': -68.3, 'Humidity': 61, 'Wind Speed': 26.4, 'Cloudiness': 40}, {'City': 'tromso', 'Country': 'NO', 'Date': 1586552052, 'Temperature': 25.84, 'Latitude': 69.65, 'Longitude': 18.96, 'Humidity': 86, 'Wind Speed': 5.82, 'C ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydata_df = pd.DataFrame(citydata)
citydata_df
# Out:
#                City Country        Date  Temperature  Latitude  Longitude  \
# 0          la ronge      CA  1586552041        28.40     55.10    -105.28
# 1    saint-philippe      RE  1586551639        69.85    -21.36      55.77
# 2          plouzane      FR  1586552042        59.05     48.38      -4.62
# 3       porto santo      PT  1586551770        64.92     33.07     -16.34
# 4          zhigansk      RU  1586552043        19.54     66.77     123.37
# ..              ...     ...         ...          ...       ...        ...
# 577     walla walla      US  1586552343        69.28     46.06    -118.34
# 578         margate      GB  1586552344        52.79     51.38       1.39
# 579          beihai      CN  1586552344        73.33     21.48     109.10
# 580          cortez      US  1586551772        59.79     37.35    -108.59
# 581          tungor      RU  1586551854        19.83     53.38     142.96
#
#      Humidity  Wind Speed  Cloudiness
# 0          63       17.22          90
# 1          78       10.29          20
# 2          67        3.36           0
# 3          77        9.17          20
# 4          94       11.48           0
# ..        ...         ...         ...
# 577        32        9.17           1
# 578        87        3.36          53
# 579        90       12.03          98
# 580        16       12.75           1
# 581        96        4.29           0
#
# [582 rows x 9 columns]

# %%
citydata_df.to_csv("city_new_data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(citydata_df["Latitude"], citydata_df["Temperature"], marker = "o", facecolors='navy', edgecolors = 'navy')

plt.title("City Latitude vs Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# %%
#Save the figure
plt.savefig("Latitude_vs_Temperature.png", dpi= 150)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(citydata_df["Latitude"], citydata_df["Humidity"], marker = "o", facecolors='navy', edgecolors = 'navy')

plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_vs_Humidity.png", dpi= 150)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(citydata_df["Latitude"], citydata_df["Cloudiness"], marker = "o", facecolors='navy', edgecolors = 'navy')

plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_vs_Cloudiness.png", dpi= 150)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(citydata_df["Latitude"], citydata_df["Wind Speed"], marker = "o", facecolors='navy', edgecolors = 'navy')

plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_vs_WindSpeed.png", dpi= 150)
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hemisphere = citydata_df.loc[citydata_df["Latitude"]>=0]
south_hemisphere = citydata_df.loc[citydata_df["Latitude"]<0]

# %% [raw]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hemisphere["Latitude"]
y_values = north_hemisphere["Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(6,10), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Northern Hemisphere Latitude vs Temperature')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hemisphere["Latitude"]
y_values = south_hemisphere["Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-17,10), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Southern Hemisphere Latitude vs Temperature')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hemisphere["Latitude"]
y_values = north_hemisphere["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(6,10), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere Latitude vs Humidity')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hemisphere["Latitude"]
y_values = south_hemisphere["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-17,15), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere Latitude vs Humidity')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hemisphere["Latitude"]
y_values = north_hemisphere["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(6,10), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere Latitude vs Cloudiness')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hemisphere["Latitude"]
y_values = south_hemisphere["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-17,10), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere Latitude vs Cloudiness')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hemisphere["Latitude"]
y_values = north_hemisphere["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(6,25), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere Latitude vs Wind Speed')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hemisphere["Latitude"]
y_values = south_hemisphere["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-17,20), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere Latitude vs Wind Speed')
plt.show()
